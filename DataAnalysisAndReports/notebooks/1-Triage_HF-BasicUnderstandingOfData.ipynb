# %% [markdown]
# # 1. Importing libraries

# %%
# Dataframe manipulation
import pandas as pd
import numpy as np
import datetime as dt

# Visualization
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# Natural Processing Language 
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Utility
import string

# %% [markdown]
# # 2. Dataset

# %% [markdown]
# There are two ways to import our data set:
# 1. Locally: if we have the repository locally, we will use the following line

# %%
# Locally method
df = pd.read_csv('../dataset/raw/TRIAGE_2024.csv')

# %% [markdown]
# 2. Remotely: if we want to connect the dataset from github, we must import it using the following line
#
# **WARNING**: every time we want to use this form, we must generate the token again.

# %%
# Github method
# train_df = pd.read_csv('https://raw.githubusercontent.com/Adriellevy/Triage_HF/main/Data%20Analysis%20and%20Reports/dataset/raw/TRIAGE%202024.csv?token=GHSAT0AAAAAACLM5VZGUTNJJPTGADJMMUKEZOQ3JLA')

# %%
df.head()
# Out:
#                                           3+-99999|a  [ñ_MJ NOMBRE Y APELLIDO  \
# 0  FECHA: 01/01/2024                             ...    NaN               NaN
# 1                                                  1  01-01              LUSI
# 2                                                  2  01-01   LO PINTO CARLOS
# 3                                                  3  01-01           BANDERA
# 4                                                  4  01-01    TOMINO EDUARDO
#
#   MOTIVO DE CONSULTA  BOX TRIAGE  ENFERMERO   MEDICO DESTINO    A  ...  \
# 0                NaN  NaN    NaN        NaN      NaN     NaN  NaN  ...
# 1       FIEBRE Y TOS   18     IV     ERIKA   RODRIGO     NaN  NaN  ...
# 2       FIEBRE Y TOS   17     IV  SOLEDAD G  SOLEDAD    alta  NaN  ...
# 3                TOS   12     IV     ERIKA   RODRIGO     NaN  NaN  ...
# 4                HTA   12     IV  SOLEDAD G  SOLEDAD    ALTA  NaN  ...
#
#   Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0         NaN          NaN          NaN         NaN          NaN          NaN
# 1         NaN          NaN          NaN         NaN          NaN          NaN
# 2         NaN          NaN          NaN         NaN          NaN          NaN
# 3         NaN          NaN          NaN         NaN          NaN          NaN
# 4         NaN          NaN          NaN         NaN          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# # 3. Data shape & duplicates

# %%
print(f'Data shape: {df.shape}')
print(f'Data duplicate values: {df.duplicated().sum()}')
# Out:
# Data shape: (2995, 25)
# Data duplicate values: 1310

# %% [markdown]
# # 4. Data types

# %%
print('Data fields type:')
display(df.info(verbose=False))
# Out:
# Data fields type:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2995 entries, 0 to 2994
# Columns: 25 entries, 3+-99999|a to Unnamed: 24
# dtypes: float64(12), object(13)
# memory usage: 585.1+ KB
# None
